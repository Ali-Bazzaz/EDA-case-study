# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from collections import Counter
from numpy import median,mean

import json
import wordcloud

# %matplotlib inline

# %%
ls
# Out:
# README.md          data/              eda_project.ipynb  images/

# %%
ls data
# Out:
# US_category_id.json  USvideos.csv

# %%
# !head -1 data/USvideos.csv
# Out:
# video_id,trending_date,title,channel_title,category_id,publish_time,tags,views,likes,dislikes,comment_count,thumbnail_link,comments_disabled,ratings_disabled,video_error_or_removed,description

# %%
data=pd.read_csv('data/USvideos.csv', delimiter=',')
data.head(3)
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
#
#                                                title    channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE     CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...  LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...     Rudy Mancuso
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
#
#                                                 tags    views   likes  \
# 0                                    SHANtell martin   748374   57527
# 1  last week tonight trump presidency|"last week ...  2418783   97185
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...  3191434  146033
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0      2966          15954  https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg
# 1      6146          12703  https://i.ytimg.com/vi/1ZAPwfrtAFY/default.jpg
# 2      5339           8181  https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
# 1              False             False                   False
# 2              False             False                   False
#
#                                          description
# 0  SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 1  One year after the presidential election, John...
# 2  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...

# %%
data.count()
# Out:
# video_id                  40949
# trending_date             40949
# title                     40949
# channel_title             40949
# category_id               40949
# publish_time              40949
# tags                      40949
# views                     40949
# likes                     40949
# dislikes                  40949
# comment_count             40949
# thumbnail_link            40949
# comments_disabled         40949
# ratings_disabled          40949
# video_error_or_removed    40949
# description               40379
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40949 entries, 0 to 40948
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                40949 non-null  object
#  1   trending_date           40949 non-null  object
#  2   title                   40949 non-null  object
#  3   channel_title           40949 non-null  object
#  4   category_id             40949 non-null  int64
#  5   publish_time            40949 non-null  object
#  6   tags                    40949 non-null  object
#  7   views                   40949 non-null  int64
#  8   likes                   40949 non-null  int64
#  9   dislikes                40949 non-null  int64
#  10  comment_count           40949 non-null  int64
#  11  thumbnail_link          40949 non-null  object
#  12  comments_disabled       40949 non-null  bool
#  13  ratings_disabled        40949 non-null  bool
#  14  video_error_or_removed  40949 non-null  bool
#  15  description             40379 non-null  object
# dtypes: bool(3), int64(5), object(8)
# memory usage: 4.2+ MB

# %%
data.describe().T
# Out:
#                  count          mean           std    min       25%       50%  \
# category_id    40949.0  1.997243e+01  7.568327e+00    1.0      17.0      24.0
# views          40949.0  2.360785e+06  7.394114e+06  549.0  242329.0  681861.0
# likes          40949.0  7.426670e+04  2.288853e+05    0.0    5424.0   18091.0
# dislikes       40949.0  3.711401e+03  2.902971e+04    0.0     202.0     631.0
# comment_count  40949.0  8.446804e+03  3.743049e+04    0.0     614.0    1856.0
#
#                      75%          max
# category_id         25.0         43.0
# views          1823157.0  225211923.0
# likes            55417.0    5613827.0
# dislikes          1938.0    1674420.0
# comment_count     5755.0    1361580.0

# %%
fig, ax = plt.subplots(figsize=(12,6)) 
_=sns.boxplot(data=data, order=['likes','dislikes','comment_count','views'],palette='Set2',fliersize=2)

# %% [markdown]
# **Given dataset represents content issues between 2006-2018**

# %%
data['date']=pd.to_datetime(data.iloc[:,5])
data['date'].dt.year.value_counts()
#data['dayofweek']=data['date'].dt.dayofweek
# data['date'].dt.day.value_counts().nlargest()
# Out:
# 2018    30279
# 2017    10428
# 2013       44
# 2015       35
# 2016       35
# 2014       32
# 2011       27
# 2012       24
# 2010       19
# 2009       14
# 2008       11
# 2006        1
# Name: date, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(8,6))
sns.histplot(data=data, x=data['date'].dt.year, discrete=True)
plt.title('Count of trending content yearly')
plt.show()
#plt.savefig('count_trends.png', dpi=100)

# %%
data.corr()
# Out:
#                         category_id     views     likes  dislikes  \
# category_id                1.000000 -0.168231 -0.173921 -0.033547
# views                     -0.168231  1.000000  0.849177  0.472213
# likes                     -0.173921  0.849177  1.000000  0.447186
# dislikes                  -0.033547  0.472213  0.447186  1.000000
# comment_count             -0.076307  0.617621  0.803057  0.700184
# comments_disabled          0.048949  0.002677 -0.028918 -0.004431
# ratings_disabled          -0.013506  0.015355 -0.020888 -0.008230
# video_error_or_removed    -0.030011 -0.002256 -0.002641 -0.001853
# max_views                       NaN       NaN       NaN       NaN
#
#                         comment_count  comments_disabled  ratings_disabled  \
# category_id                 -0.076307           0.048949         -0.013506
# views                        0.617621           0.002677          0.015355
# likes                        0.803057          -0.028918         -0.020888
# dislikes                     0.700184          -0.004431         -0.008230
# comment_count                1.000000          -0.028277         -0.013819
# comments_disabled           -0.028277           1.000000          0.319230
# ratings_disabled            -0.013819           0.319230          1.000000
# video_error_or_removed      -0.003725          -0.002970         -0.001526
# max_views                         NaN                NaN               NaN
#
#                         video_error_or_removed  max_views
# category_id                          -0.030011        NaN
# views                                -0.002256        NaN
# likes                                -0.002641        NaN
# dislikes                             -0.001853        NaN
# comment_count                        -0.003725        NaN
# comments_disabled                    -0.002970        NaN
# ratings_disabled                     -0.001526        NaN
# video_error_or_removed                1.000000        NaN
# max_views                                  NaN        NaN

# %% [markdown]
# **LETS SEE CORRELATION BETWEEN VARIABLES**

# %%
fig,ax=plt.subplots(figsize=(10,8))
sns.heatmap(data.corr(), annot=True, vmin=-1, vmax=1, center=0, linewidths=2, linecolor='black')
plt.title('Heatmap', fontsize=14)
plt.show()

plt.savefig('data_correlation.png')

# %% [markdown]
# **LETS SEE THE RELATIONSHIPS BETWEEN TWO VARIABLES**

# %%
z=data[['likes','dislikes','views','comment_count']]
sns.pairplot(data=z)
plt.title('Paiplot',fontsize=14)
plt.show()

# %% [markdown]
# **WHAT CATEGORY HAS MORE CONTENT?**

# %%
data.category_id.value_counts()
# Out:
# 24    9964
# 10    6472
# 26    4146
# 23    3457
# 22    3210
# 25    2487
# 28    2401
# 1     2345
# 17    2174
# 27    1656
# 15     920
# 20     817
# 19     402
# 2      384
# 29      57
# 43      57
# Name: category_id, dtype: int64

# %% [markdown]
# **So, we can see the top categories, but what is the name of these?**

# %%
with open('data/US_category_id.json') as f:
    categories = json.load(f)["items"]
cat_dict = {}
for cat in categories:
    cat_dict[int(cat["id"])] = cat["snippet"]["title"]
data['category_name'] = data['category_id'].map(cat_dict)

# %%
data.category_name.value_counts()
# Out:
# Entertainment            9964
# Music                    6472
# Howto & Style            4146
# Comedy                   3457
# People & Blogs           3210
# News & Politics          2487
# Science & Technology     2401
# Film & Animation         2345
# Sports                   2174
# Education                1656
# Pets & Animals            920
# Gaming                    817
# Travel & Events           402
# Autos & Vehicles          384
# Shows                      57
# Nonprofits & Activism      57
# Name: category_name, dtype: int64

# %% [markdown]
# **Counts of times video was in YouTube trend in each category**

# %%
fig, ax = plt.subplots(figsize=(8,8))

_=sns.countplot(y="category_name", data=data,facecolor=(0, 0, 0, 0),linewidth=5, orient='h',
                   edgecolor=sns.color_palette("dark", 7),ax=ax)
_.set_title('Number of trending videos in each category')
plt.savefig('num_trends_by_category.png')
plt.show()

# %%
cat_name = data["category_name"].value_counts().to_frame().reset_index()
cat_name.rename(columns={"index": "category_name", "category_name": "No_of_videos"}, inplace=True)
fig, ax = plt.subplots(figsize=(8,6))
_ = sns.barplot(x="category_name", y="No_of_videos", data=cat_name, 
                palette=sns.cubehelix_palette(n_colors=16, reverse=True), ax=ax)
_ = ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
_ = ax.set(xlabel="Category", ylabel="No. of videos")

#plt.savefig('Youtube category.png')

# %% [markdown]
# **WHAT VIDEO CONTENT DOES THE  ENTERTAINMENT CATEGORY CONSIST OF?**

# %%
max_trend=data[data['category_name']=='Entertainment']
s=max_trend[['title','channel_title']]
s.describe().T
# Out:
#               count unique                                         top freq
# title          9964   1645  WE MADE OUR MOM CRY...HER DREAM CAME TRUE!   30
# channel_title  9964    478                                     Netflix  193

# %%
max_trend.channel_title.value_counts().nlargest(20)
# Out:
# Netflix                                 193
# TheEllenShow                            193
# Saturday Night Live                     175
# The Late Show with Stephen Colbert      161
# HellthyJunkFood                         153
# Warner Bros. Pictures                   150
# FBE                                     149
# Good Mythical Morning                   147
# Vanity Fair                             144
# The Late Late Show with James Corden    137
# The Voice                               121
# Jimmy Kimmel Live                       118
# James Charles                           118
# Marvel Entertainment                    117
# Binging with Babish                     112
# Complex                                 109
# E! Entertainment                        108
# Star Wars                               106
# Universal Pictures                      106
# WIRED                                   103
# Name: channel_title, dtype: int64

# %%
cdf = max_trend.groupby("channel_title").size().reset_index(name="video_count") \
    .sort_values("video_count", ascending=False).head(10)

fig, ax = plt.subplots(figsize=(8,8))
_ = sns.barplot(x="video_count", y="channel_title", data=cdf,
                palette=sns.cubehelix_palette(n_colors=20, reverse=True), ax=ax)
_ = ax.set(xlabel="No. of videos", ylabel="Channel")

# %% [markdown]
# **What are the most common words in trending video titles?**

# %%
title_words = list(max_trend["title"].apply(lambda x: x.split()))
title_words = [x for y in title_words for x in y]
Counter(title_words).most_common(25)
# Out:
# [('|', 3655),
#  ('-', 2622),
#  ('The', 1819),
#  ('Trailer', 931),
#  ('the', 885),
#  ('Official', 738),
#  ('a', 673),
#  ('to', 610),
#  ('with', 598),
#  ('2018', 595),
#  ('&', 564),
#  ('and', 557),
#  ('A', 551),
#  ('on', 529),
#  ('of', 461),
#  ('I', 433),
#  ('in', 403),
#  ('[HD]', 345),
#  ('for', 324),
#  ('Season', 323),
#  ('With', 320),
#  ('To', 261),
#  ('In', 252),
#  ('Star', 252),
#  ('How', 236)]

# %%
wc = wordcloud.WordCloud(width=1200, height=500, 
                         collocations=False, background_color="black", 
                         colormap="tab20b").generate(" ".join(title_words))
plt.figure(figsize=(15,10))
plt.imshow(wc, interpolation='bilinear')
_ = plt.axis("off")

# %% [markdown]
# **LETS SEE LIKES/DISLIKES/VIEWS DISTRIBUTION AMONG TRENDING CONTENT**

# %%
data.groupby('category_name').agg('median').sort_values(by='views',ascending=False)
# Out:
#                        category_id      views    likes  dislikes  \
# category_name
# Gaming                        20.0  1494142.0  51057.0    1956.0
# Music                         10.0  1434128.0  62280.5    1243.5
# Film & Animation               1.0  1274578.0  25176.0    1022.0
# Shows                         43.0  1155692.0  21537.0     465.0
# Comedy                        23.0   980236.0  30214.0     956.0
# Entertainment                 24.0   734704.0  16234.0     627.0
# People & Blogs                22.0   599139.0  19438.0     555.5
# Science & Technology          28.0   585748.0  16328.0     589.0
# Sports                        17.0   559352.0   5700.5     343.0
# Howto & Style                 26.0   502783.0  21492.5     502.5
# Travel & Events               19.0   494825.5  11634.0     351.0
# Pets & Animals                15.0   444501.5  14431.5     276.0
# Education                     27.0   419440.5  13508.5     397.0
# Autos & Vehicles               2.0   406278.0   5916.0     279.0
# News & Politics               25.0   244014.0   1920.0     344.0
# Nonprofits & Activism         29.0    73649.0   2721.0     122.0
#
#                        comment_count  comments_disabled  ratings_disabled  \
# category_name
# Gaming                        8871.0              False             False
# Music                         3906.0              False             False
# Film & Animation              2636.0              False             False
# Shows                         1648.0              False             False
# Comedy                        2604.0              False             False
# Entertainment                 1693.5              False             False
# People & Blogs                1678.0              False             False
# Science & Technology          1734.0              False             False
# Sports                        1127.5              False             False
# Howto & Style                 1842.0              False             False
# Travel & Events               1674.5              False             False
# Pets & Animals                1173.0              False             False
# Education                     1466.5              False             False
# Autos & Vehicles               916.0              False             False
# News & Politics                866.0              False             False
# Nonprofits & Activism          570.0              False             False
#
#                        video_error_or_removed
# category_name
# Gaming                                  False
# Music                                   False
# Film & Animation                        False
# Shows                                   False
# Comedy                                  False
# Entertainment                           False
# People & Blogs                          False
# Science & Technology                    False
# Sports                                  False
# Howto & Style                           False
# Travel & Events                         False
# Pets & Animals                          False
# Education                               False
# Autos & Vehicles                        False
# News & Politics                         False
# Nonprofits & Activism                   False

# %%
cols=['views', 'likes','dislikes','comment_count']
data.groupby('category_name')[cols].max().sort_values(by='views', ascending=False)
# Out:
#                            views    likes  dislikes  comment_count
# category_name
# Music                  225211923  5613827    343541        1228655
# Entertainment          149376127  3093544   1674420        1361580
# People & Blogs          56111957  2032463    228426         383762
# Film & Animation        54863912   922355     38082         108849
# Howto & Style           54155921   605954     66632         203884
# Science & Technology    42799458   564804     47469         180913
# Comedy                  29178096   865679     29865          81051
# Sports                  29090799  1121217    176903          83660
# Autos & Vehicles        25244097    97030     12290          10591
# Nonprofits & Activism   24286474  1988746    497847         658130
# Travel & Events         23932421    42447      9000          13631
# Gaming                  16935442   444203    212976         144795
# News & Politics         10277358   163338    132439          38936
# Education                7349435   240989     11270          28835
# Pets & Animals           6187457   178243      4899          44063
# Shows                    1445949    33261       616           2181

# %%
#using barplot to represent central tendency of numaric variables

fig, ax = plt.subplots(figsize=(8,8))
_=sns.barplot(data=data, x='likes', y='category_name', orient='h', estimator=median, capsize=.4,
                  palette=sns.cubehelix_palette(n_colors=20, reverse=True),ax=ax)
_.set_title('Video Category likes');

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,8))
_=sns.barplot(data=data, x='dislikes', y='category_name', orient='h', estimator=median,capsize=.4,
                  palette=sns.cubehelix_palette(n_colors=20, reverse=True),ax=ax)
_.set_title('Video Category dislikes');

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,8))
_=sns.barplot(data=data, x='views', y='category_name', orient='h', estimator=median, capsize=.4,
                  palette=sns.cubehelix_palette(n_colors=20, reverse=True),ax=ax)
_.set_title('Video Category views');

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,8))
_=sns.barplot(data=data, x='comment_count', y='category_name', orient='h', estimator=median, capsize=.4,
                  palette=sns.cubehelix_palette(n_colors=20, reverse=True),ax=ax)
_.set_title('Video Category views');

plt.show()

# %% [markdown]
# **MOST POPULAR CONTENT IN MUSIC CATEGORY**

# %%
music=data[data['category_name']=='Music']
x=music[['title','channel_title']]
x.describe().T
# Out:
#               count unique                                  top freq
# title          6472    821  Charlie Puth - BOY [Official Audio]   29
# channel_title  6472    443                          PTXofficial   90

# %%
music.groupby(['title','channel_title', 'date'])[['views','likes','dislikes']].max().sort_values(by='views',ascending=False)
# Out:
#                                                                                                       views  \
# title                                              channel_title       date
# Childish Gambino - This Is America (Official Vi... ChildishGambinoVEVO 2018-05-06 04:00:07+00:00  225211923
# Ariana Grande - No Tears Left To Cry               ArianaGrandeVevo    2018-04-20 04:00:03+00:00  148689896
# Becky G, Natti Natasha - Sin Pijama (Official V... BeckyGVEVO          2018-04-20 10:40:51+00:00  139334502
# BTS (방탄소년단) 'FAKE LOVE' Official MV                ibighit             2018-05-18 09:00:02+00:00  123010920
# The Weeknd - Call Out My Name (Official Video)     TheWeekndVEVO       2018-04-12 16:00:04+00:00  122544931
# ...                                                                                                     ...
# mad eye moody - moving eyeball prop                daronjay            2017-11-14 13:25:56+00:00       3896
# IoT kit robot #3                                   eba era             2014-03-07 22:39:36+00:00       3456
# Carol of the Pugs                                  Maggie Smith Kühn   2017-11-28 20:10:12+00:00       3411
# Electromechanical display rear view                negermano           2017-12-18 17:10:48+00:00       2717
# Tony Rizzo Embarrassed by Dan Le Batard and Joe... The Scam On Demand  2018-01-24 20:05:58+00:00       1808
#
#                                                                                                     likes  \
# title                                              channel_title       date
# Childish Gambino - This Is America (Official Vi... ChildishGambinoVEVO 2018-05-06 04:00:07+00:00  5023450
# Ariana Grande - No Tears Left To Cry               ArianaGrandeVevo    2018-04-20 04:00:03+00:00  3094021
# Becky G, Natti Natasha - Sin Pijama (Official V... BeckyGVEVO          2018-04-20 10:40:51+00:00  1425496
# BTS (방탄소년단) 'FAKE LOVE' Official MV                ibighit             2018-05-18 09:00:02+00:00  5613827
# The Weeknd - Call Out My Name (Official Video)     TheWeekndVEVO       2018-04-12 16:00:04+00:00  1427436
# ...                                                                                                   ...
# mad eye moody - moving eyeball prop                daronjay            2017-11-14 13:25:56+00:00        9
# IoT kit robot #3                                   eba era             2014-03-07 22:39:36+00:00        4
# Carol of the Pugs                                  Maggie Smith Kühn   2017-11-28 20:10:12+00:00       41
# Electromechanical display rear view                negermano           2017-12-18 17:10:48+00:00        5
# Tony Rizzo Embarrassed by Dan Le Batard and Joe... The Scam On Demand  2018-01-24 20:05:58+00:00       16
#
#                                                                                                   dislikes
# title                                              channel_title       date
# Childish Gambino - This Is America (Official Vi... ChildishGambinoVEVO 2018-05-06 04:00:07+00:00    343541
# Ariana Grande - No Tears Left To Cry               ArianaGrandeVevo    2018-04-20 04:00:03+00:00    129502
# Becky G, Natti Natasha - Sin Pijama (Official V... BeckyGVEVO          2018-04-20 10:40:51+00:00    119798
# BTS (방탄소년단) 'FAKE LOVE' Official MV                ibighit             2018-05-18 09:00:02+00:00    206892
# The Weeknd - Call Out My Name (Official Video)     TheWeekndVEVO       2018-04-12 16:00:04+00:00     40837
# ...                                                                                                    ...
# mad eye moody - moving eyeball prop                daronjay            2017-11-14 13:25:56+00:00         0
# IoT kit robot #3                                   eba era             2014-03-07 22:39:36+00:00         4
# Carol of the Pugs                                  Maggie Smith Kühn   2017-11-28 20:10:12+00:00         0
# Electromechanical display rear view                negermano           2017-12-18 17:10:48+00:00         0
# Tony Rizzo Embarrassed by Dan Le Batard and Joe... The Scam On Demand  2018-01-24 20:05:58+00:00         3
#
# [827 rows x 3 columns]

# %% [markdown]
# **Most viewed video at Youtube in beetween 2017-2018**
# https://www.youtube.com/watch?v=VYOjWnS4cMY

# %%
data.groupby(['category_name','title','channel_title','date'])[['views','likes','dislikes']].max().sort_values(by='views',
                                                                            ascending=False).head(10)
# Out:
#                                                                                                                      views  \
# category_name title                                              channel_title        date
# Music         Childish Gambino - This Is America (Official Vi... ChildishGambinoVEVO  2018-05-06 04:00:07+00:00  225211923
# Entertainment YouTube Rewind: The Shape of 2017 | #YouTubeRewind YouTube Spotlight    2017-12-06 17:58:51+00:00  149376127
# Music         Ariana Grande - No Tears Left To Cry               ArianaGrandeVevo     2018-04-20 04:00:03+00:00  148689896
#               Becky G, Natti Natasha - Sin Pijama (Official V... BeckyGVEVO           2018-04-20 10:40:51+00:00  139334502
#               BTS (방탄소년단) 'FAKE LOVE' Official MV                ibighit              2018-05-18 09:00:02+00:00  123010920
#               The Weeknd - Call Out My Name (Official Video)     TheWeekndVEVO        2018-04-12 16:00:04+00:00  122544931
#               Luis Fonsi, Demi Lovato - Échame La Culpa          LuisFonsiVEVO        2017-11-17 05:00:01+00:00  102012605
#               Cardi B, Bad Bunny & J Balvin - I Like It [Offi... Cardi B              2018-05-29 14:05:10+00:00   94254507
# Entertainment Marvel Studios' Avengers: Infinity War Official... Marvel Entertainment 2017-11-29 13:26:24+00:00   91933007
# Music         Maluma - El Préstamo (Official Video)              MalumaVEVO           2018-03-09 11:00:01+00:00   87264467
#
#                                                                                                                    likes  \
# category_name title                                              channel_title        date
# Music         Childish Gambino - This Is America (Official Vi... ChildishGambinoVEVO  2018-05-06 04:00:07+00:00  5023450
# Entertainment YouTube Rewind: The Shape of 2017 | #YouTubeRewind YouTube Spotlight    2017-12-06 17:58:51+00:00  3093544
# Music         Ariana Grande - No Tears Left To Cry               ArianaGrandeVevo     2018-04-20 04:00:03+00:00  3094021
#               Becky G, Natti Natasha - Sin Pijama (Official V... BeckyGVEVO           2018-04-20 10:40:51+00:00  1425496
#               BTS (방탄소년단) 'FAKE LOVE' Official MV                ibighit              2018-05-18 09:00:02+00:00  5613827
#               The Weeknd - Call Out My Name (Official Video)     TheWeekndVEVO        2018-04-12 16:00:04+00:00  1427436
#               Luis Fonsi, Demi Lovato - Échame La Culpa          LuisFonsiVEVO        2017-11-17 05:00:01+00:00  2376636
#               Cardi B, Bad Bunny & J Balvin - I Like It [Offi... Cardi B              2018-05-29 14:05:10+00:00  1816753
# Entertainment Marvel Studios' Avengers: Infinity War Official... Marvel Entertainment 2017-11-29 13:26:24+00:00  2625661
# Music         Maluma - El Préstamo (Official Video)              MalumaVEVO           2018-03-09 11:00:01+00:00   815369
#
#                                                                                                                  dislikes
# category_name title                                              channel_title        date
# Music         Childish Gambino - This Is America (Official Vi... ChildishGambinoVEVO  2018-05-06 04:00:07+00:00    343541
# Entertainment YouTube Rewind: The Shape of 2017 | #YouTubeRewind YouTube Spotlight    2017-12-06 17:58:51+00:00   1643059
# Music         Ariana Grande - No Tears Left To Cry               ArianaGrandeVevo     2018-04-20 04:00:03+00:00    129502
#               Becky G, Natti Natasha - Sin Pijama (Official V... BeckyGVEVO           2018-04-20 10:40:51+00:00    119798
#               BTS (방탄소년단) 'FAKE LOVE' Official MV                ibighit              2018-05-18 09:00:02+00:00    206892
#               The Weeknd - Call Out My Name (Official Video)     TheWeekndVEVO        2018-04-12 16:00:04+00:00     40837
#               Luis Fonsi, Demi Lovato - Échame La Culpa          LuisFonsiVEVO        2017-11-17 05:00:01+00:00    117196
#               Cardi B, Bad Bunny & J Balvin - I Like It [Offi... Cardi B              2018-05-29 14:05:10+00:00    102474
# Entertainment Marvel Studios' Avengers: Infinity War Official... Marvel Entertainment 2017-11-29 13:26:24+00:00     53709
# Music         Maluma - El Préstamo (Official Video)              MalumaVEVO           2018-03-09 11:00:01+00:00     71494

# %% [markdown]
# **The most viewble content was trending in the middle of 2018**

# %%
#from operator import itemgetter

df_ = data.reset_index()
date_view = df_[['trending_date', 'views']].values
date_view_counts = {}
for i in date_view:
    if i[0] not in date_view_counts:
        date_view_counts[i[0]] = i[1]
    else:
        date_view_counts[i[0]] += i[1]
dv_df = pd.DataFrame.from_dict(date_view_counts, orient = 'index')
dv_df.plot(rot=0, figsize=(20, 10), title="Total Views of Each Day")
plt.xlabel("Date (Year.Day.Month)")
plt.ylabel("Views")
plt.show()

# %%
views=data.groupby(['category_name','title','channel_title'])[['views','likes','dislikes']].max().sort_values(by='views',
                                                                            ascending=False)

views.count()
# Out:
# views       6484
# likes       6484
# dislikes    6484
# dtype: int64

# %%
from scipy import stats
from scipy.stats import skew 
skew(views.views)
# Out:
# 14.240959285809675

# %%
gambino=data[data['title']=='Childish Gambino - This Is America (Official Video)'][['views','trending_date','likes']]

# %%
gambino['views'].max()-gambino['views'].min()
# Out:
# 193563469

# %%
gambino.describe().T
# Out:
#        count          mean           std         min          25%  \
# views   25.0  1.503396e+08  5.724536e+07  31648454.0  116581406.0
# likes   25.0  3.868033e+06  1.038329e+06   1405355.0    3388289.0
#
#                50%          75%          max
# views  162556776.0  196222618.0  225211923.0
# likes    4202645.0    4656929.0    5023450.0

# %%
df_ = gambino.reset_index()
date_view = df_[['trending_date', 'views']].values
date_view_counts = {}
for i in date_view:
    if i[0] not in date_view_counts:
        date_view_counts[i[0]] = i[1]
    else:
        date_view_counts[i[0]] += i[1]
dv_df = pd.DataFrame.from_dict(date_view_counts, orient = 'index')
dv_df.plot(rot=0, figsize=(20, 10), title="Views of Childish Gambino - This Is America (Official Video)")
plt.xlabel("Date (Year.Day.Month)")
plt.ylabel("Views")
plt.show()

# %% [markdown]
# **Youtube content that has been trending max time is**

# %%
data['title'].value_counts().nlargest(5)
# Out:
# WE MADE OUR MOM CRY...HER DREAM CAME TRUE!                       30
# Sam Smith - Pray (Official Video) ft. Logic                      29
# The ULTIMATE $30,000 Gaming PC Setup                             29
# YoungBoy Never Broke Again Goes Sneaker Shopping With Complex    29
# Why I'm So Scared (being myself and crying too much)             29
# Name: title, dtype: int64

# %%
max_trend=data[data['title']=='WE MADE OUR MOM CRY...HER DREAM CAME TRUE!'][['views','trending_date']].max()
max_trend
# Out:
# views            10381263
# trending_date    18.31.05
# dtype: object

# %%
exp=data.groupby('title')[['views', 'likes','category_name', 'trending_date']].max().sort_values(by='views',ascending=False)
exp
# Out:
#                                                         views    likes  \
# title
# Childish Gambino - This Is America (Official Vi...  225211923  5023450
# YouTube Rewind: The Shape of 2017 | #YouTubeRewind  149376127  3093544
# Ariana Grande - No Tears Left To Cry                148689896  3094021
# Becky G, Natti Natasha - Sin Pijama (Official V...  139334502  1425496
# BTS (방탄소년단) 'FAKE LOVE' Official MV                 123010920  5613827
# ...                                                       ...      ...
# Huffy Metaloid Bicycle Commercial 1997                    773        2
# Raw: 3 South Carolina Deputies, 1 Officer Shot            748        9
# Artwork Forge                                             745        1
# Coach Taggart Monday Presser Ahead of Arizona             704       10
# 1 dead, others injured after Ky. school shooting          559        9
#
#                                                       category_name  \
# title
# Childish Gambino - This Is America (Official Vi...            Music
# YouTube Rewind: The Shape of 2017 | #YouTubeRewind    Entertainment
# Ariana Grande - No Tears Left To Cry                          Music
# Becky G, Natti Natasha - Sin Pijama (Official V...            Music
# BTS (방탄소년단) 'FAKE LOVE' Official MV                           Music
# ...                                                             ...
# Huffy Metaloid Bicycle Commercial 1997                    Education
# Raw: 3 South Carolina Deputies, 1 Officer Shot      News & Politics
# Artwork Forge                                                Sports
# Coach Taggart Monday Presser Ahead of Arizona                Sports
# 1 dead, others injured after Ky. school shooting    News & Politics
#
#                                                    trending_date
# title
# Childish Gambino - This Is America (Official Vi...      18.31.05
# YouTube Rewind: The Shape of 2017 | #YouTubeRewind      17.14.12
# Ariana Grande - No Tears Left To Cry                    18.30.04
# Becky G, Natti Natasha - Sin Pijama (Official V...      18.30.04
# BTS (방탄소년단) 'FAKE LOVE' Official MV                     18.31.05
# ...                                                          ...
# Huffy Metaloid Bicycle Commercial 1997                  17.14.11
# Raw: 3 South Carolina Deputies, 1 Officer Shot          18.18.01
# Artwork Forge                                           18.29.01
# Coach Taggart Monday Presser Ahead of Arizona           17.17.11
# 1 dead, others injured after Ky. school shooting        18.28.01
#
# [6455 rows x 4 columns]

# %%
sns.scatterplot(x='views', y='likes', data=exp)
plt.title('Strength of assocciation')
#plt.savefig('views_likes_scatter.png')
plt.show()

# %%
exp.category_name.value_counts()
# Out:
# Entertainment            1641
# Music                     821
# Howto & Style             601
# Comedy                    548
# News & Politics           511
# People & Blogs            504
# Sports                    458
# Science & Technology      391
# Film & Animation          320
# Education                 257
# Pets & Animals            143
# Gaming                    104
# Autos & Vehicles           72
# Travel & Events            65
# Nonprofits & Activism      15
# Shows                       4
# Name: category_name, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(8,8))
_=sns.barplot(data=exp, x='views', y='category_name', orient='h',  capsize=.3,
                  palette=sns.cubehelix_palette(n_colors=20, reverse=True),ax=ax)
_.set_title('Video Category views');

plt.show()
